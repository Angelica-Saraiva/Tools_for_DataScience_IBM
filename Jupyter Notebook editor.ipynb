# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Angélica Saraiva**
#
# Data Science Student

# %% [markdown]
# _I'm interested in Data Science because I love using and analyze data. I like health research and expect that I will be capable to learn how to do this work on a better way_

# %% [markdown]
# ### The code below is an example that Jupyter Nootebooks can make simple calculations

# %%
23+5
# Out:
# 28

# %% [markdown]
# #### A bullet (unordered) list
# - Jupyter
# - RStudio
# #### An ordered (numbered) list
# 1. Jupyter
# 2. RStudio
# #### A table
# | Country | State | City |
# |-------------|-----------|-----------|
# | Brazil | Pernambuco | Recife |
# | Brazil | Rio de Janeiro | Niterói |
# | Brazil | São Paulo| Santos |
